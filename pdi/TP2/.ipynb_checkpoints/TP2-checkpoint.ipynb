# %%
# %matplotlib inline 

import numpy as np
import os
from matplotlib import pyplot as plt

#loading the images
import skimage.io as io

# %%
import random
from skimage.transform import resize

fns = os.listdir('MNIST/3')

imgs = []

for i in [3, 8]:
    for fn in os.listdir('MNIST/' + str(i)):
        img = io.imread('MNIST/%d/%s' % (i, fn), dtype=np.float64)
        img = resize(img, (29, 29))
        img = img / 255
        imgs.append((img, 1 if i == 8 else 0))

random.shuffle(imgs)

inputs = np.zeros((len(imgs), 29, 29))
outputs = np.zeros((len(imgs)))

for i, (img, cls) in enumerate(imgs):
    inputs[i] = img
    outputs[i] = cls
    
inputs = inputs.reshape(len(inputs), 29, 29, 1)
# Out:
# /home/rafael/mestrado/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
import math
from scipy.special import expit
from scipy.signal import correlate

#derro/df1[i] = sum in j: derro/dint[j] * dint[j]*df1[i]
def grad_filter1(mat1, grad_mat2):
    a = np.zeros(grad_mat2.shape)
    
    for filter_i in np.ndindex(grad_mat2.shape):
        a[filter_i] = 0
        
        for mat2_i in np.ndindex(grad_mat2.shape):
            a[filter_i] += grad_mat2[mat2_i] * mat1[filter_i[0] + mat2_i[0], filter_i[1] + mat2_i[1]]
            
    return a

def grad_mat2(factor, filter2):
    return factor * filter2

def grad_filter2(factor, mat2):
    return factor * mat2
    

# sigma((mat conv filter1) conv filter2) 
def train_step(mat1, filter1, filter2, coeff, correct, lr):
    mat2 = correlate(mat1, filter1, mode='valid')
    v = correlate(mat2, filter2, mode='valid')[0][0]
    v2 = coeff[0] * v
    final = expit(v2)
    error = 0.5 * (final - correct)**2
    
    #derro/dv2 = derro/dfinal * dfinal/dv2
    derro_dv2 = (final - correct) * final * (1 - final)
    
    #derro/dv = derro/dv2 * dv2/dv
    derro_dv = derro_dv2 * coeff[0]
    
    print('error:', 'final:', final, error, 'factor:', derro_dv2, 'v:', v)
    
    gfilter2 = grad_filter2(derro_dv, mat2)
    gmat2 = grad_mat2(derro_dv, filter2)
    gfilter1 = grad_filter1(mat1, gmat2)
    
    #derro/dcoeff = derro/dv2 * dv2/dcoeff = 
    gcoeff = derro_dv2 * v
    
    coeff[0] -= lr * gcoeff
    
    for i in np.ndindex(filter1.shape):
        filter1 -= lr * gfilter1[i]
        filter2 -= lr * gfilter2[i]

    return 1 if final >= 0.5 else 0

# %%
from IPython.display import clear_output

factor = 0.1
filter1 = (np.random.rand(15,15) - 0.5) * factor
filter2 = (np.random.rand(15,15) - 0.5) * factor
coeff = np.random.rand(1) - 0.5

# img, cls = imgs[8]

# print(cls)

# for i in range(30):
#     train_step(img, filter1, filter2, cls, 0.01)

for i in range(10):
    right = 0
    for i, (img, cls) in enumerate(imgs):
        res = train_step(img, filter1, filter2, coeff, cls, 0.1)
#         if res == cls: right += 1
#         clear_output(wait=True)
#         print(i+1, '=>', 100 * right / (i+1))
# Out:
# error: 0.1241977433171032 factor: -0.12459693874082868 final: 0.5016070961237445 v: -0.09605994317634409
# error: 0.1786626513324096 factor: 0.1437280534606617 final: 0.5977669300528586 v: -5.815954750362834
# error: 0.4998306469737134 factor: -0.00016931000318646912 final: 0.00016936736893943732 v: -561.1550484561349
# error: 0.4748275180771895 factor: -0.024213871359400507 final: 0.025497544305619017 v: -609.9681383555592
# error: 0.0 factor: 0.0 final: 1.0 v: -394.38001259377626
# error: 0.0 factor: 0.0 final: 1.0 v: -352.0358342974284
# error: 0.5 factor: 0.0 final: 1.0 v: -313.61858567797674
# error: 0.5 factor: 0.0 final: 1.0 v: -341.84137210933284
# error: 0.5 factor: 0.0 final: 1.0 v: -168.44737251316852
# error: 0.0 factor: 0.0 final: 1.0 v: -355.02382295236436
# error: 0.5 factor: 0.0 final: 1.0 v: -408.5347619058844
# error: 0.0 factor: 0.0 final: 1.0 v: -349.5622914985638
# error: 0.5 factor: 0.0 final: 1.0 v: -273.7002755757837
# error: 0.5 factor: 0.0 final: 1.0 v: -332.91159716391917
# error: 0.5 factor: 0.0 final: 1.0 v: -305.9684154561052
# error: 0.0 factor: 0.0 final: 1.0 v: -231.12142617659
# error: 0.5 factor: 0.0 final: 1.0 v: -336.97804792256176
# error: 0.5 factor: 0.0 final: 1.0 v: -262.01607103057813
# error: 0.5 factor: 0.0 final: 1.0 v: -269.65450069515816
# error: 0.5 factor: 0.0 final: 1.0 v: -232.63301515016104
# error: 0.0 factor: 0.0 final: 1.0 v: -246.94513666037042
# error: 0.0 factor: 0.0 final: 1.0 v: -260.1121567182589
# error: 0.0 factor: 0.0 final: 1.0 v: -303.05149696851527
# error: 0.0 factor: 0.0 final: 1.0 v: -356.83530274499515
# error: 0.5 factor: 0.0 final: 1.0 v: -426.86374536651675
# error: 0.0 factor: 0.0 final: 1.0 v: -368.31424853333476
# error: 0.0 factor: 0.0 final: 1.0 v: -429.47921169444027
# error: 0.0 factor: 0.0 final: 1.0 v: -460.7362212320362
# error: 0.5 factor: 0.0 final: 1.0 v: -306.7067076055943
# error: 0.5 factor: 0.0 final: 1.0 v: -242.85283609596712
# error: 0.5 factor: 0.0 final: 1.0 v: -388.4448893030373
# error: 0.0 factor: 0.0 final: 1.0 v: -240.9713614414268
# error: 0.0 factor: 0.0 final: 1.0 v: -358.66442284668585
# error: 0.5 factor: 0.0 final: 1.0 v: -331.89753827320516
# error: 0.5 factor: 0.0 final: 1.0 v: -309.3814464067473
# error: 0.0 factor: 0.0 final: 1.0 v: -291.59957438433025
# error: 0.0 factor: 0.0 final: 1.0 v: -275.3335342712088
# error: 0.5 factor: 0.0 final: 1.0 v: -314.87489055489556
# error: 0.0 factor: 0.0 final: 1.0 v: -295.4603529362517
# error: 0.0 factor: 0.0 final: 1.0 v: -428.2641753631115
# error: 0.5 factor: 0.0 final: 1.0 v: -271.3927433797734
# error: 0.5 factor: 0.0 final: 1.0 v: -302.9815893684291
# error: 0.5 factor: 0.0 final: 1.0 v: -274.0921554076892
# error: 0.0 factor: 0.0 final: 1.0 v: -330.48923750352924
# error: 0.5 factor: 0.0 final: 1.0 v: -309.20492947237653
# error: 0.5 factor: 0.0 final: 1.0 v: -226.71673948528525
# error: 0.0 factor: 0.0 final: 1.0 v: -615.222186945657
# error: 0.5 factor: 0.0 final: 1.0 v: -388.82468937846
# error: 0.0 factor: 0.0 final: 1.0 v: -383.6158785813768
# error: 0.5 factor: 0.0 final: 1.0 v: -338.1697080079163
# error: 0.0 factor: 0.0 final: 1.0 v: -318.4620807859656
# error: 0.0 factor: 0.0 final: 1.0 v: -329.43307722799574
# error: 0.0 factor: 0.0 final: 1.0 v: -305.80712440321656
# error: 0.0 factor: 0.0 final: 1.0 v: -196.60643282579744
# error: 0.0 factor: 0.0 final: 1.0 v: -393.1978129166329
# error: 0.0 factor: 0.0 final: 1.0 v: -304.0973358060461
# error: 0.0 factor: 0.0 final: 1.0 v: -424.2893148919077
# error: 0.5 factor: 0.0 final: 1.0 v: -238.31962238197755
# error: 0.5 factor: 0.0 final: 1.0 v: -288.86215999157406
# error: 0.5 factor: 0.0 final: 1.0 v: -357.1032308058057
# error: 0.5 factor: 0.0 final: 1.0 v: -295.82295138738544
# error: 0.5 factor: 0.0 final: 1.0 v: -206.29035206153426
# error: 0.0 factor: 0.0 final: 1.0 v: -345.31926484390345
# error: 0.5 factor: 0.0 final: 1.0 v: -298.10615383704715
# error: 0.0 factor: 0.0 final: 1.0 v: -243.85422038499877
# error: 0.5 factor: 0.0 final: 1.0 v: -227.83926171032377
# error: 0.5 factor: 0.0 final: 1.0 v: -304.15666743413965
# error: 0.0 factor: 0.0 final: 1.0 v: -253.3965767748275
# error: 0.5 factor: 0.0 final: 1.0 v: -150.0679784652266
# error: 0.0 factor: 0.0 final: 1.0 v: -269.67687569102327
# error: 0.5 factor: 0.0 final: 1.0 v: -338.0255722067204
# error: 0.0 factor: 0.0 final: 1.0 v: -260.2122236346234
# error: 0.5 factor: 0.0 final: 1.0 v: -261.26894075326373
# error: 0.5 factor: 0.0 final: 1.0 v: -202.0515919783647
# error: 0.0 factor: 0.0 final: 1.0 v: -355.35425939537186
# error: 0.0 factor: 0.0 final: 1.0 v: -265.6642442023677
# error: 0.0 factor: 0.0 final: 1.0 v: -226.46690990296588
# error: 0.5 factor: 0.0 final: 1.0 v: -315.3664996779073
# error: 0.5 factor: 0.0 final: 1.0 v: -417.17266228578364
# error: 0.0 factor: 0.0 final: 1.0 v: -377.0926629662338
# error: 0.0 factor: 0.0 final: 1.0 v: -258.6710707025558
# error: 0.5 factor: 0.0 final: 1.0 v: -269.177773768713
# error: 0.0 factor: 0.0 final: 1.0 v: -290.7445279918144
# error: 0.0 factor: 0.0 final: 1.0 v: -226.0897949301545
# error: 0.0 factor: 0.0 final: 1.0 v: -355.77783967922613
# error: 0.0 factor: 0.0 final: 1.0 v: -370.42112290709684
# error: 0.5 factor: 0.0 final: 1.0 v: -343.4977899859143
# error: 0.0 factor: 0.0 final: 1.0 v: -358.134778921507
# error: 0.0 factor: 0.0 final: 1.0 v: -290.8738806181537
# error: 0.0 factor: 0.0 final: 1.0 v: -300.3403843198643
# error: 0.5 factor: 0.0 final: 1.0 v: -339.45662439901514
# error: 0.0 factor: 0.0 final: 1.0 v: -315.3531257175841
# error: 0.0 factor: 0.0 final: 1.0 v: -412.9988641740223
# error: 0.0 factor: 0.0 final: 1.0 v: -344.7943771908495
# error: 0.5 factor: 0.0 final: 1.0 v: -268.6354366661284
# error: 0.0 factor: 0.0 final: 1.0 v: -443.333555339472
# error: 0.0 factor: 0.0 final: 1.0 v: -267.70094536756267
# error: 0.5 factor: 0.0 final: 1.0 v: -239.75053871717392
# error: 0.0 factor: 0.0 final: 1.0 v: -262.2436863365699
# error: 0.5 factor: 0.0 final: 1.0 v: -320.60474052606094
# error: 0.5 factor: 0.0 final: 1.0 v: -164.74257568189958
# error: 0.5 factor: 0.0 final: 1.0 v: -328.2474240630122
# error: 0.0 factor: 0.0 final: 1.0 v: -295.66056524386096
# error: 0.0 factor: 0.0 final: 1.0 v: -301.41180107152627
# error: 0.5 factor: 0.0 final: 1.0 v: -295.41701712534166
# error: 0.0 factor: 0.0 final: 1.0 v: -352.57931782428614
# error: 0.0 factor: 0.0 final: 1.0 v: -321.5490546214596
# error: 0.0 factor: 0.0 final: 1.0 v: -316.8479145847194
# error: 0.0 factor: 0.0 final: 1.0 v: -324.2508324056923
# error: 0.5 factor: 0.0 final: 1.0 v: -329.22125754437445
# error: 0.0 factor: 0.0 final: 1.0 v: -288.8703180298652
# error: 0.0 factor: 0.0 final: 1.0 v: -315.91672819044584
# error: 0.0 factor: 0.0 final: 1.0 v: -361.1502503939554
# error: 0.0 factor: 0.0 final: 1.0 v: -293.94881277339766
# error: 0.5 factor: 0.0 final: 1.0 v: -346.6644465251063
# error: 0.5 factor: 0.0 final: 1.0 v: -307.02345732063867
# error: 0.0 factor: 0.0 final: 1.0 v: -466.6320392834994
# error: 0.5 factor: 0.0 final: 1.0 v: -397.01655162566055
# error: 0.5 factor: 0.0 final: 1.0 v: -376.7311157974342
# error: 0.0 factor: 0.0 final: 1.0 v: -324.7284377209005
# error: 0.0 factor: 0.0 final: 1.0 v: -431.0476865699423
# error: 0.0 factor: 0.0 final: 1.0 v: -247.78061883169954
# error: 0.5 factor: 0.0 final: 1.0 v: -399.8132287125677
# error: 0.5 factor: 0.0 final: 1.0 v: -412.49025493704164
# error: 0.0 factor: 0.0 final: 1.0 v: -392.2023873581599
# error: 0.0 factor: 0.0 final: 1.0 v: -402.9116152461379
# error: 0.5 factor: 0.0 final: 1.0 v: -185.5467957677541
# error: 0.0 factor: 0.0 final: 1.0 v: -272.4671255380128
# error: 0.0 factor: 0.0 final: 1.0 v: -379.04327269514465
# error: 0.5 factor: 0.0 final: 1.0 v: -264.4851354317372
# error: 0.5 factor: 0.0 final: 1.0 v: -293.7278099366209
# error: 0.5 factor: 0.0 final: 1.0 v: -435.4342112531274
# error: 0.0 factor: 0.0 final: 1.0 v: -344.0516069133061
# error: 0.5 factor: 0.0 final: 1.0 v: -336.6964577755205
# error: 0.5 factor: 0.0 final: 1.0 v: -275.41107509635845
# error: 0.5 factor: 0.0 final: 1.0 v: -326.6870818653953
# error: 0.5 factor: 0.0 final: 1.0 v: -344.4340997024837
# error: 0.5 factor: 0.0 final: 1.0 v: -361.16851923594834
# error: 0.5 factor: 0.0 final: 1.0 v: -363.52209978650836
# error: 0.5 factor: 0.0 final: 1.0 v: -300.8604379166007
# error: 0.0 factor: 0.0 final: 1.0 v: -363.79462978389745
# error: 0.0 factor: 0.0 final: 1.0 v: -368.64300607664234
# error: 0.5 factor: 0.0 final: 1.0 v: -368.43205674926475
# error: 0.0 factor: 0.0 final: 1.0 v: -326.80718044719305
# error: 0.0 factor: 0.0 final: 1.0 v: -302.78996052340403
# error: 0.5 factor: 0.0 final: 1.0 v: -295.54792036486117
# error: 0.0 factor: 0.0 final: 1.0 v: -259.6407314350521
# error: 0.5 factor: 0.0 final: 1.0 v: -318.5054244401325
# error: 0.5 factor: 0.0 final: 1.0 v: -219.35770485962303
# error: 0.0 factor: 0.0 final: 1.0 v: -584.0616266520036
# error: 0.5 factor: 0.0 final: 1.0 v: -450.58590884700305
# error: 0.0 factor: 0.0 final: 1.0 v: -379.2946519884132
# error: 0.5 factor: 0.0 final: 1.0 v: -265.62175674370627
# error: 0.5 factor: 0.0 final: 1.0 v: -286.2429018657844
# error: 0.5 factor: 0.0 final: 1.0 v: -228.30987697692652
# error: 0.5 factor: 0.0 final: 1.0 v: -200.74560207043146
# error: 0.5 factor: 0.0 final: 1.0 v: -367.12895129396026
# error: 0.5 factor: 0.0 final: 1.0 v: -428.36891512244324
# error: 0.0 factor: 0.0 final: 1.0 v: -504.3504753903282
# error: 0.0 factor: 0.0 final: 1.0 v: -263.3953371552414
# error: 0.5 factor: 0.0 final: 1.0 v: -316.8369385729893
# error: 0.0 factor: 0.0 final: 1.0 v: -292.27483073140485
# error: 0.5 factor: 0.0 final: 1.0 v: -467.4448309529477
# error: 0.0 factor: 0.0 final: 1.0 v: -254.12350066005888
# error: 0.0 factor: 0.0 final: 1.0 v: -203.98796976947838
# error: 0.5 factor: 0.0 final: 1.0 v: -198.38195523277562
# error: 0.0 factor: 0.0 final: 1.0 v: -347.24132712173946
# error: 0.0 factor: 0.0 final: 1.0 v: -387.95862495255165
# error: 0.5 factor: 0.0 final: 1.0 v: -317.0819536870225
# error: 0.5 factor: 0.0 final: 1.0 v: -299.90764218764616
# error: 0.5 factor: 0.0 final: 1.0 v: -297.38371046525987
# error: 0.5 factor: 0.0 final: 1.0 v: -394.93539317732404
# error: 0.0 factor: 0.0 final: 1.0 v: -365.0722663734664
# error: 0.0 factor: 0.0 final: 1.0 v: -306.11353522170066
# error: 0.0 factor: 0.0 final: 1.0 v: -243.63415411871196
# error: 0.0 factor: 0.0 final: 1.0 v: -226.59264494180684
# error: 0.0 factor: 0.0 final: 1.0 v: -327.6852586992886
# error: 0.5 factor: 0.0 final: 1.0 v: -368.02278647820185
# error: 0.0 factor: 0.0 final: 1.0 v: -352.47217480668974
# error: 0.0 factor: 0.0 final: 1.0 v: -246.6854772116474
# error: 0.5 factor: 0.0 final: 1.0 v: -403.4353884327023
# error: 0.0 factor: 0.0 final: 1.0 v: -348.5794966394252
# error: 0.5 factor: 0.0 final: 1.0 v: -226.45395320680467
# error: 0.5 factor: 0.0 final: 1.0 v: -265.8609090937028
# error: 0.5 factor: 0.0 final: 1.0 v: -437.647924862234
# error: 0.0 factor: 0.0 final: 1.0 v: -351.52242762879683
# error: 0.5 factor: 0.0 final: 1.0 v: -327.8739374376677
# error: 0.5 factor: 0.0 final: 1.0 v: -288.31971309209797
# error: 0.5 factor: 0.0 final: 1.0 v: -271.78198349298947
# error: 0.5 factor: 0.0 final: 1.0 v: -221.6094433434875
# error: 0.5 factor: 0.0 final: 1.0 v: -555.149874636053
# error: 0.0 factor: 0.0 final: 1.0 v: -233.69655463065666
# error: 0.5 factor: 0.0 final: 1.0 v: -234.78929656780795
# error: 0.5 factor: 0.0 final: 1.0 v: -194.98906299379772
# error: 0.5 factor: 0.0 final: 1.0 v: -328.67635238801887
# error: 0.0 factor: 0.0 final: 1.0 v: -298.30950060019484
# error: 0.0 factor: 0.0 final: 1.0 v: -336.87313979262905
# error: 0.0 factor: 0.0 final: 1.0 v: -242.1260749414304
# error: 0.5 factor: 0.0 final: 1.0 v: -353.194832490773
# error: 0.5 factor: 0.0 final: 1.0 v: -317.65809532495643
# error: 0.5 factor: 0.0 final: 1.0 v: -293.75623895689375
# error: 0.0 factor: 0.0 final: 1.0 v: -273.1318193373117
# error: 0.5 factor: 0.0 final: 1.0 v: -357.4519728888106
# error: 0.5 factor: 0.0 final: 1.0 v: -226.90992385255996
# error: 0.0 factor: 0.0 final: 1.0 v: -247.61478704325899
# error: 0.0 factor: 0.0 final: 1.0 v: -307.47539997365357
# error: 0.5 factor: 0.0 final: 1.0 v: -300.74083035224197
# error: 0.0 factor: 0.0 final: 1.0 v: -385.9224118224592
# error: 0.0 factor: 0.0 final: 1.0 v: -246.41182981381277
# error: 0.5 factor: 0.0 final: 1.0 v: -223.89547509040534
# error: 0.0 factor: 0.0 final: 1.0 v: -301.85100959750054
# error: 0.0 factor: 0.0 final: 1.0 v: -170.02743945256896
# error: 0.5 factor: 0.0 final: 1.0 v: -298.156287687611
# error: 0.0 factor: 0.0 final: 1.0 v: -252.71216296845063
# error: 0.5 factor: 0.0 final: 1.0 v: -267.27269575521905
# error: 0.5 factor: 0.0 final: 1.0 v: -231.3719033072054
# error: 0.0 factor: 0.0 final: 1.0 v: -446.7545242247296
# error: 0.5 factor: 0.0 final: 1.0 v: -315.3901981218851
# error: 0.5 factor: 0.0 final: 1.0 v: -194.01772608616284
# error: 0.5 factor: 0.0 final: 1.0 v: -214.43582943944523
# error: 0.5 factor: 0.0 final: 1.0 v: -160.57314943044454
# error: 0.0 factor: 0.0 final: 1.0 v: -227.9013963698769
# error: 0.0 factor: 0.0 final: 1.0 v: -209.90057763716194
# error: 0.0 factor: 0.0 final: 1.0 v: -408.45145042848435
# error: 0.0 factor: 0.0 final: 1.0 v: -367.1281817861044
# error: 0.5 factor: 0.0 final: 1.0 v: -269.1409492292992
# error: 0.0 factor: 0.0 final: 1.0 v: -373.76653179194784
# error: 0.5 factor: 0.0 final: 1.0 v: -266.8390484101477
# error: 0.5 factor: 0.0 final: 1.0 v: -348.1425017562994
# error: 0.0 factor: 0.0 final: 1.0 v: -408.6849449808649
# error: 0.0 factor: 0.0 final: 1.0 v: -424.92837118194416
# error: 0.5 factor: 0.0 final: 1.0 v: -323.02742618443966
# error: 0.5 factor: 0.0 final: 1.0 v: -367.653162227572
# error: 0.0 factor: 0.0 final: 1.0 v: -354.7780821146493
# error: 0.0 factor: 0.0 final: 1.0 v: -282.99120140526793
# error: 0.5 factor: 0.0 final: 1.0 v: -244.24672924520274
# error: 0.5 factor: 0.0 final: 1.0 v: -337.62556465776356
# error: 0.0 factor: 0.0 final: 1.0 v: -384.37646864824904
# error: 0.5 factor: 0.0 final: 1.0 v: -369.36979039940263
# error: 0.5 factor: 0.0 final: 1.0 v: -450.86706205600603
# error: 0.5 factor: 0.0 final: 1.0 v: -260.6938210370139
# error: 0.0 factor: 0.0 final: 1.0 v: -483.07069915581616
# error: 0.5 factor: 0.0 final: 1.0 v: -301.53904217803085
# error: 0.0 factor: 0.0 final: 1.0 v: -356.7141489672345
# error: 0.5 factor: 0.0 final: 1.0 v: -253.18642248755452
# error: 0.5 factor: 0.0 final: 1.0 v: -268.4475986209181
# error: 0.5 factor: 0.0 final: 1.0 v: -307.89460013306257
# error: 0.5 factor: 0.0 final: 1.0 v: -366.7866723340689
# error: 0.0 factor: 0.0 final: 1.0 v: -252.42451344371125
# error: 0.5 factor: 0.0 final: 1.0 v: -264.860318506661
# error: 0.5 factor: 0.0 final: 1.0 v: -295.0879996179075
# error: 0.0 factor: 0.0 final: 1.0 v: -272.5016690235387
# error: 0.5 factor: 0.0 final: 1.0 v: -269.7972070335244
# error: 0.5 factor: 0.0 final: 1.0 v: -454.469306128364
# error: 0.0 factor: 0.0 final: 1.0 v: -361.89441934835503
# error: 0.5 factor: 0.0 final: 1.0 v: -328.2314318079795
# error: 0.5 factor: 0.0 final: 1.0 v: -374.8554405768485
# error: 0.0 factor: 0.0 final: 1.0 v: -418.25487292407786
# error: 0.5 factor: 0.0 final: 1.0 v: -320.9560796593372
# error: 0.5 factor: 0.0 final: 1.0 v: -395.52367565235477
# error: 0.5 factor: 0.0 final: 1.0 v: -298.88211601412144
# error: 0.0 factor: 0.0 final: 1.0 v: -387.9214167161794
# error: 0.0 factor: 0.0 final: 1.0 v: -317.5301323443642
# error: 0.0 factor: 0.0 final: 1.0 v: -371.5619893126401
# error: 0.5 factor: 0.0 final: 1.0 v: -180.68566375192756
# error: 0.0 factor: 0.0 final: 1.0 v: -328.5513738934379
# error: 0.5 factor: 0.0 final: 1.0 v: -389.31601800101504
# error: 0.0 factor: 0.0 final: 1.0 v: -359.21566780359365
# error: 0.5 factor: 0.0 final: 1.0 v: -206.40209913604548
# error: 0.5 factor: 0.0 final: 1.0 v: -213.53582816319604
# error: 0.5 factor: 0.0 final: 1.0 v: -422.4141570442355
# error: 0.0 factor: 0.0 final: 1.0 v: -276.2178296890761
# error: 0.5 factor: 0.0 final: 1.0 v: -329.5613601365148
# error: 0.5 factor: 0.0 final: 1.0 v: -321.7359703368534
# error: 0.0 factor: 0.0 final: 1.0 v: -381.33335010048455
# error: 0.5 factor: 0.0 final: 1.0 v: -405.0984259859949
# error: 0.0 factor: 0.0 final: 1.0 v: -307.0854172518977
# error: 0.0 factor: 0.0 final: 1.0 v: -294.5175738656022
# error: 0.5 factor: 0.0 final: 1.0 v: -382.51597696451853
# error: 0.0 factor: 0.0 final: 1.0 v: -334.1085248186775
# error: 0.5 factor: 0.0 final: 1.0 v: -288.4164693130595
# error: 0.0 factor: 0.0 final: 1.0 v: -336.6016004532749
# error: 0.0 factor: 0.0 final: 1.0 v: -248.14657751376632
# error: 0.5 factor: 0.0 final: 1.0 v: -375.4546932935584
# error: 0.5 factor: 0.0 final: 1.0 v: -235.6588652793228
# error: 0.5 factor: 0.0 final: 1.0 v: -325.1689020653088
# error: 0.0 factor: 0.0 final: 1.0 v: -336.32016799293893
# error: 0.5 factor: 0.0 final: 1.0 v: -490.98020434243205
# error: 0.5 factor: 0.0 final: 1.0 v: -359.61342928647537
# error: 0.5 factor: 0.0 final: 1.0 v: -302.02820159769493
# error: 0.5 factor: 0.0 final: 1.0 v: -281.9539490741177
# error: 0.5 factor: 0.0 final: 1.0 v: -327.7839162613485
# error: 0.5 factor: 0.0 final: 1.0 v: -315.6174413581343
# error: 0.5 factor: 0.0 final: 1.0 v: -114.60875544430299
# error: 0.5 factor: 0.0 final: 1.0 v: -257.8236911002569
# error: 0.0 factor: 0.0 final: 1.0 v: -332.4545439866016
# error: 0.5 factor: 0.0 final: 1.0 v: -357.8700091395891
# error: 0.0 factor: 0.0 final: 1.0 v: -380.77708128709264
# error: 0.5 factor: 0.0 final: 1.0 v: -314.5636409222657
# error: 0.5 factor: 0.0 final: 1.0 v: -238.0532776196573
# error: 0.5 factor: 0.0 final: 1.0 v: -309.4020982077108
# error: 0.5 factor: 0.0 final: 1.0 v: -387.42581586132616
# error: 0.5 factor: 0.0 final: 1.0 v: -423.06512743992903
# error: 0.5 factor: 0.0 final: 1.0 v: -277.60245738277615
# error: 0.0 factor: 0.0 final: 1.0 v: -367.0311341450983
# error: 0.0 factor: 0.0 final: 1.0 v: -358.69539694732833
# error: 0.5 factor: 0.0 final: 1.0 v: -314.65568717467545
# error: 0.5 factor: 0.0 final: 1.0 v: -272.5465841482601
# error: 0.0 factor: 0.0 final: 1.0 v: -311.1967623185357
# error: 0.5 factor: 0.0 final: 1.0 v: -470.267162800573
# error: 0.5 factor: 0.0 final: 1.0 v: -325.4386979565361
# error: 0.5 factor: 0.0 final: 1.0 v: -323.1428639653415
# error: 0.0 factor: 0.0 final: 1.0 v: -221.74279451177276
# error: 0.5 factor: 0.0 final: 1.0 v: -356.70174077099
# error: 0.0 factor: 0.0 final: 1.0 v: -307.57272198405616
# error: 0.0 factor: 0.0 final: 1.0 v: -333.58256710278215
# error: 0.0 factor: 0.0 final: 1.0 v: -365.7193201942206
# error: 0.5 factor: 0.0 final: 1.0 v: -379.05100893914624
# error: 0.0 factor: 0.0 final: 1.0 v: -373.6660374613974
# error: 0.0 factor: 0.0 final: 1.0 v: -307.7382237994429
# error: 0.0 factor: 0.0 final: 1.0 v: -358.42011503997946
# error: 0.5 factor: 0.0 final: 1.0 v: -252.44351392421075
# error: 0.0 factor: 0.0 final: 1.0 v: -365.2219601150824
# error: 0.5 factor: 0.0 final: 1.0 v: -323.78262038810544
# error: 0.5 factor: 0.0 final: 1.0 v: -366.0396660606381
# error: 0.0 factor: 0.0 final: 1.0 v: -559.0591289520212
# error: 0.5 factor: 0.0 final: 1.0 v: -254.31445094941736
# error: 0.0 factor: 0.0 final: 1.0 v: -361.68863798882944
# error: 0.5 factor: 0.0 final: 1.0 v: -359.9237596136844
# error: 0.0 factor: 0.0 final: 1.0 v: -510.88173711155764
# error: 0.5 factor: 0.0 final: 1.0 v: -363.7145854408246
# error: 0.0 factor: 0.0 final: 1.0 v: -353.9254033252391
# error: 0.5 factor: 0.0 final: 1.0 v: -382.4169740602944
# error: 0.0 factor: 0.0 final: 1.0 v: -414.82405194154524
# error: 0.0 factor: 0.0 final: 1.0 v: -288.1737537769653
# error: 0.0 factor: 0.0 final: 1.0 v: -245.64619666962636
# error: 0.0 factor: 0.0 final: 1.0 v: -464.3288647206531
# error: 0.0 factor: 0.0 final: 1.0 v: -392.27545967174984
# error: 0.5 factor: 0.0 final: 1.0 v: -192.65900123771124
# error: 0.5 factor: 0.0 final: 1.0 v: -339.2900506209953
# error: 0.0 factor: 0.0 final: 1.0 v: -356.83586411122167
# error: 0.5 factor: 0.0 final: 1.0 v: -256.34532239206584
# error: 0.0 factor: 0.0 final: 1.0 v: -433.41915555631425
# error: 0.0 factor: 0.0 final: 1.0 v: -378.5360834980703
# error: 0.0 factor: 0.0 final: 1.0 v: -351.51633861952314
# error: 0.0 factor: 0.0 final: 1.0 v: -315.7224369177038
# error: 0.5 factor: 0.0 final: 1.0 v: -284.94987073726423
# error: 0.5 factor: 0.0 final: 1.0 v: -427.6602132773961
# error: 0.5 factor: 0.0 final: 1.0 v: -234.53213805605225
# error: 0.5 factor: 0.0 final: 1.0 v: -249.3208873118634
# error: 0.0 factor: 0.0 final: 1.0 v: -375.85568530446454
# error: 0.0 factor: 0.0 final: 1.0 v: -268.6181678029288
# error: 0.5 factor: 0.0 final: 1.0 v: -582.9581946720969
# error: 0.5 factor: 0.0 final: 1.0 v: -287.770934784958
# error: 0.5 factor: 0.0 final: 1.0 v: -293.1840936397559
# error: 0.0 factor: 0.0 final: 1.0 v: -275.1564474541578
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-401-25976cf54b76> in <module>()
#      16     right = 0
#      17     for i, (img, cls) in enumerate(imgs):
# ---> 18         res = train_step(img, filter1, filter2, coeff, cls, 0.1)
#      19 #         if res == cls: right += 1
#      20 #         clear_output(wait=True)
#
# <ipython-input-400-4b938b94df0d> in train_step(mat1, filter1, filter2, coeff, correct, lr)
#      40     gfilter2 = grad_filter2(derro_dv, mat2)
#      41     gmat2 = grad_mat2(derro_dv, filter2)
# ---> 42     gfilter1 = grad_filter1(mat1, gmat2)
#      43
#      44     #derro/dcoeff = derro/dv2 * dv2/dcoeff =
#
# <ipython-input-400-4b938b94df0d> in grad_filter1(mat1, grad_mat2)
#      11
#      12         for mat2_i in np.ndindex(grad_mat2.shape):
# ---> 13             a[filter_i] += grad_mat2[mat2_i] * mat1[filter_i[0] + mat2_i[0], filter_i[1] + mat2_i[1]]
#      14
#      15     return a
#
# KeyboardInterrupt:

# %%
import keras

from keras.initializers import RandomUniform

from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten

model = Sequential()

firstFilter = Conv2D(1, kernel_size=(15, 15), kernel_initializer=RandomUniform(minval=-0.05, maxval=0.05), activation=None, input_shape=(29, 29, 1), use_bias=False)

model.add(firstFilter)

secondFilter = Conv2D(1, (15, 15), kernel_initializer=RandomUniform(minval=-0.05, maxval=0.05), activation=None, use_bias=False)
model.add(secondFilter)

model.add(Flatten())
model.add(Dense(1, activation='sigmoid', kernel_initializer=RandomUniform(minval=-0.05, maxval=0.05), use_bias=False))

print(model.summary())

model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.SGD(lr=0.01),
              metrics=['accuracy'])

train_size = int(len(inputs) * 0.9)
train_in = inputs[:train_size]
train_out = outputs[:train_size]
test_in = inputs[train_size:]
test_out = outputs[train_size:]

#draw_filters(model)

model.fit(inputs, outputs,
          epochs=10,
          verbose=1, 
          validation_data=(test_in, test_out), 
          batch_size=1)

draw_filters(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_68 (Conv2D)           (None, 15, 15, 1)         225
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 1, 1, 1)           225
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 1)                 0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 1
# =================================================================
# Total params: 451
# Trainable params: 451
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 8414 samples, validate on 842 samples
# Epoch 1/10
# 8414/8414 [==============================] - 32s 4ms/step - loss: 0.2015 - acc: 0.9180 - val_loss: 0.1252 - val_acc: 0.9549
# Epoch 2/10
#  949/8414 [==>...........................] - ETA: 26s - loss: 0.1508 - acc: 0.9557
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-394-06d751b89cca> in <module>()
#      36           verbose=1,
#      37           validation_data=(test_in, test_out),
# ---> 38           batch_size=1)
#      39
#      40 draw_filters(model)
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1114
#    1115           feed_dict_tensor[subfeed_t] = np_val
# -> 1116           feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1117
#    1118     # Create a fetch handler to take care of the structure of fetches.
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in name(self)
#     333     if not self._op.name:
#     334       raise ValueError("Operation was not named: %s" % self._op)
# --> 335     return "%s:%d" % (self._op.name, self._value_index)
#     336
#     337   @property
#
# ~/mestrado/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in name(self)
#    1851   def name(self):
#    1852     """The full name of this operation."""
# -> 1853     if self._c_op:
#    1854       return c_api.TF_OperationName(self._c_op)
#    1855     else:
#
# KeyboardInterrupt:

# %%
filter1 = model.layers[0].get_weights()[0].reshape(15,15)
filter2 = model.layers[1].get_weights()[0].reshape(15,15)

coeff = model.layers[3].get_weights()[0][0]

count = 0
for i, (img, cls) in enumerate(imgs):
    result1 = model.predict(img.reshape(1, 29,29, 1))[0][0]
    inter = correlate(img, filter1, mode='valid') 
    v = correlate(inter, filter2, mode='valid')[0][0] 
    result2 = expit(coeff * v)
    
    r1 = 1 if result1 > 0.5 else 0
    r2 = 1 if result2 > 0.5 else 0
    
    if r1 != r2:
        print(r1, r2)
        count += 1

print(count)

# print(model.layers[3])
# Out:
# 0

# %%
def draw_filters(model):    
    plt.subplot(121)
    weights = model.layers[0].get_weights()[0]
    weights = weights.reshape(15,15)
    plt.imshow(weights, cmap="gray")
    
    plt.subplot(122)
    weights = model.layers[1].get_weights()[0]
    weights = weights.reshape(15,15)
    plt.imshow(weights, cmap="gray")
    
    plt.show()
    
    weights = model.layers[3].get_weights()
    print(weights)
    
draw_filters(model)
# Out:
# [array([[1.7791573]], dtype=float32)]

# %%
import scipy.ndimage.filters

from scipy.special import expit

def relu(mat):
    mat[mat < 0] = 0

id = 16

img = inputs[id].reshape(29,29)
plt.imshow(img, cmap="gray")
plt.show()

res = model.predict(inputs[id:id+1], verbose=1)[0][0]
print("Predict:", res)

img = inputs[id:id+1].reshape(29,29)
print(img.shape)

filter1 = model.layers[0].get_weights()[0].reshape(15,15)
bias1 = model.layers[0].get_weights()[1]
filter2 = model.layers[1].get_weights()[0].reshape(15,15)
bias2 = model.layers[1].get_weights()[1]

res = scipy.ndimage.filters.convolve(img, filter1)[7:22, 7:22]
relu(res)
res = scipy.ndimage.filters.convolve(res, filter2)[7:8, 7:8]
relu(res)
res = res[0,0]
print("Before last layer:", res)

weights = model.layers[3].get_weights()
coeff = weights[0][0,0]
bias = weights[1][0]

res = coeff * res + bias
print("Before sigma:", res)
res = expit(res)
print("After sigma:", res)
# Out:
# 1/1 [==============================] - 0s 1ms/step
# Predict: 0.88647544
# (29, 29)
# Before last layer: 1.8052598353147828
# Before sigma: -1.4317497053237687
# After sigma: 0.1928262062646259

# %%
from keras.models import Model

id=25
imgKeras = inputs[id:id+1]
#imgKeras = np.ones((1,29,29,1))
#print(imgKeras.shape)
imgConv = imgKeras.reshape(29,29)

res = model.predict(imgKeras)
print(res[0][0])

plt.subplot(121)
plt.imshow(imgConv, cmap="gray")

intermediate_layer_model = Model(inputs=firstFilter.input, outputs=firstFilter.output)
intermediate_output = intermediate_layer_model.predict(imgKeras).reshape(15,15)

plt.subplot(122)
plt.imshow(intermediate_output, cmap="gray")
plt.show()

#print(model.layers[0].get_weights())
# filter1 = model.layers[0].get_weights()[0].reshape(15,15)
# res = scipy.ndimage.filters.convolve(imgConv, filter1)[7:22, 7:22]
# relu(res)
# print(res[0])
# Out:
# 0.097064756
